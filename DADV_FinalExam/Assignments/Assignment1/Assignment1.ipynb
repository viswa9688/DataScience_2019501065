# %%
import numpy as np
import pandas as pd

# %%
basics = pd.read_csv("basics-data.tsv", delimiter = "\t")
basics.head(5)
# Out:
# C:\Users\HARIKA\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
ratings = pd.read_csv("title-data.tsv", delimiter = "\t")
ratings.head(5)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1669
# 1  tt0000002            6.1       207
# 2  tt0000003            6.5      1392
# 3  tt0000004            6.2       123
# 4  tt0000005            6.2      2181

# %%
data = ratings[ratings['averageRating'] > 8.0]
data.head(5)
# Out:
#         tconst  averageRating  numVotes
# 273  tt0000361            8.1        10
# 298  tt0000417            8.2     43815
# 338  tt0000505            8.1        11
# 606  tt0000961            8.2        13
# 686  tt0001089            8.3        19

# %%
final_ratings = data.sort_values('numVotes', ascending = False)

# %%
final_ratings.head(20)
# Out:
#            tconst  averageRating  numVotes
# 81773   tt0111161            9.3   2326344
# 246046  tt0468569            9.0   2288140
# 582089  tt1375666            8.8   2051750
# 98054   tt0137523            8.8   1842531
# 81557   tt0110912            8.9   1814425
# 80684   tt0109830            8.8   1795075
# 423587  tt0944947            9.3   1747397
# 95969   tt0133093            8.7   1664961
# 89544   tt0120737            8.8   1649550
# 112867  tt0167260            8.9   1632805
# 45695   tt0068646            9.2   1607349
# 574519  tt1345836            8.4   1507477
# 387580  tt0816692            8.6   1496586
# 112868  tt0167261            8.7   1476251
# 413725  tt0903747            9.5   1439589
# 84325   tt0114369            8.6   1434119
# 666688  tt1853728            8.4   1347347
# 115288  tt0172495            8.5   1333117
# 206372  tt0372784            8.2   1300916
# 74992   tt0102926            8.6   1261810

# %%
output = pd.merge(final_ratings, basics, on= 'tconst')
output.head(10)
# Out:
#       tconst  averageRating  numVotes titleType  \
# 0  tt0111161            9.3   2326344     movie
# 1  tt0468569            9.0   2288140     movie
# 2  tt1375666            8.8   2051750     movie
# 3  tt0137523            8.8   1842531     movie
# 4  tt0110912            8.9   1814425     movie
# 5  tt0109830            8.8   1795075     movie
# 6  tt0944947            9.3   1747397  tvSeries
# 7  tt0133093            8.7   1664961     movie
# 8  tt0120737            8.8   1649550     movie
# 9  tt0167260            8.9   1632805     movie
#
#                                         primaryTitle  \
# 0                           The Shawshank Redemption
# 1                                    The Dark Knight
# 2                                          Inception
# 3                                         Fight Club
# 4                                       Pulp Fiction
# 5                                       Forrest Gump
# 6                                    Game of Thrones
# 7                                         The Matrix
# 8  The Lord of the Rings: The Fellowship of the Ring
# 9      The Lord of the Rings: The Return of the King
#
#                                        originalTitle isAdult startYear  \
# 0                           The Shawshank Redemption       0      1994
# 1                                    The Dark Knight       0      2008
# 2                                          Inception       0      2010
# 3                                         Fight Club       0      1999
# 4                                       Pulp Fiction       0      1994
# 5                                       Forrest Gump       0      1994
# 6                                    Game of Thrones       0      2011
# 7                                         The Matrix       0      1999
# 8  The Lord of the Rings: The Fellowship of the Ring       0      2001
# 9      The Lord of the Rings: The Return of the King       0      2003
#
#   endYear runtimeMinutes                   genres
# 0      \N            142                    Drama
# 1      \N            152       Action,Crime,Drama
# 2      \N            148  Action,Adventure,Sci-Fi
# 3      \N            139                    Drama
# 4      \N            154              Crime,Drama
# 5      \N            142            Drama,Romance
# 6    2019             57   Action,Adventure,Drama
# 7      \N            136            Action,Sci-Fi
# 8      \N            178   Action,Adventure,Drama
# 9      \N            201   Action,Adventure,Drama

# %%
output = output[output['titleType'] == 'movie']

# %%
output.head(10)
# Out:
#        tconst  averageRating  numVotes titleType  \
# 0   tt0111161            9.3   2326344     movie
# 1   tt0468569            9.0   2288140     movie
# 2   tt1375666            8.8   2051750     movie
# 3   tt0137523            8.8   1842531     movie
# 4   tt0110912            8.9   1814425     movie
# 5   tt0109830            8.8   1795075     movie
# 7   tt0133093            8.7   1664961     movie
# 8   tt0120737            8.8   1649550     movie
# 9   tt0167260            8.9   1632805     movie
# 10  tt0068646            9.2   1607349     movie
#
#                                          primaryTitle  \
# 0                            The Shawshank Redemption
# 1                                     The Dark Knight
# 2                                           Inception
# 3                                          Fight Club
# 4                                        Pulp Fiction
# 5                                        Forrest Gump
# 7                                          The Matrix
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9       The Lord of the Rings: The Return of the King
# 10                                      The Godfather
#
#                                         originalTitle isAdult startYear  \
# 0                            The Shawshank Redemption       0      1994
# 1                                     The Dark Knight       0      2008
# 2                                           Inception       0      2010
# 3                                          Fight Club       0      1999
# 4                                        Pulp Fiction       0      1994
# 5                                        Forrest Gump       0      1994
# 7                                          The Matrix       0      1999
# 8   The Lord of the Rings: The Fellowship of the Ring       0      2001
# 9       The Lord of the Rings: The Return of the King       0      2003
# 10                                      The Godfather       0      1972
#
#    endYear runtimeMinutes                   genres
# 0       \N            142                    Drama
# 1       \N            152       Action,Crime,Drama
# 2       \N            148  Action,Adventure,Sci-Fi
# 3       \N            139                    Drama
# 4       \N            154              Crime,Drama
# 5       \N            142            Drama,Romance
# 7       \N            136            Action,Sci-Fi
# 8       \N            178   Action,Adventure,Drama
# 9       \N            201   Action,Adventure,Drama
# 10      \N            175              Crime,Drama

# %%
output['originalTitle'].head(20)
# Out:
# 0                              The Shawshank Redemption
# 1                                       The Dark Knight
# 2                                             Inception
# 3                                            Fight Club
# 4                                          Pulp Fiction
# 5                                          Forrest Gump
# 7                                            The Matrix
# 8     The Lord of the Rings: The Fellowship of the Ring
# 9         The Lord of the Rings: The Return of the King
# 10                                        The Godfather
# 11                                The Dark Knight Rises
# 12                                         Interstellar
# 13                The Lord of the Rings: The Two Towers
# 15                                                Se7en
# 16                                     Django Unchained
# 17                                            Gladiator
# 18                                        Batman Begins
# 19                             The Silence of the Lambs
# 20                                 Inglourious Basterds
# 21                                  Saving Private Ryan
# Name: originalTitle, dtype: object

# %%
basics.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear         object
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
basics['startYear'] = pd.to_numeric(basics['startYear'], errors='coerce')

# %%
year = basics[(basics['startYear'] >= 2000) & (basics['titleType'] == 'movie')]
year.head(10)
# Out:
#           tconst titleType                               primaryTitle  \
# 15184  tt0015414     movie                     La tierra de los toros
# 16662  tt0016906     movie                                 Frivolinas
# 19706  tt0019996     movie                                    Hongxia
# 34811  tt0035423     movie                             Kate & Leopold
# 61132  tt0062336     movie  El Tango del Viudo y Su Espejo Deformante
# 63462  tt0064730     movie                 Japan Organized Crime Boss
# 64107  tt0065392     movie                         Bucharest Memories
# 67686  tt0069049     movie                 The Other Side of the Wind
# 85714  tt0087608     movie                           Leila wa al ziap
# 86825  tt0088751     movie                          The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 15184                     La tierra de los toros       0     2000.0      \N
# 16662                                 Frivolinas       0     2014.0      \N
# 19706                                    Hongxia       0     2011.0      \N
# 34811                             Kate & Leopold       0     2001.0      \N
# 61132  El Tango del Viudo y Su Espejo Deformante       0     2020.0      \N
# 63462                 Nihon boryoku-dan: Kumicho       0     2000.0      \N
# 64107                       Amintiri bucurestene       0     2020.0      \N
# 67686                 The Other Side of the Wind       0     2018.0      \N
# 85714                           Leila wa al ziap       0     2008.0      \N
# 86825                          The Naked Monster       0     2005.0      \N
#
#       runtimeMinutes                  genres
# 15184             60                      \N
# 16662             80          Comedy,Musical
# 19706             94                      \N
# 34811            118  Comedy,Fantasy,Romance
# 61132             70                   Drama
# 63462             97            Action,Crime
# 64107             \N             Documentary
# 67686            122                   Drama
# 85714             90             Documentary
# 86825            100    Comedy,Horror,Sci-Fi

# %%
output1 = pd.merge(year, ratings, on= 'tconst')
output1.head(10)
# Out:
#       tconst titleType                               primaryTitle  \
# 0  tt0015414     movie                     La tierra de los toros
# 1  tt0016906     movie                                 Frivolinas
# 2  tt0019996     movie                                    Hongxia
# 3  tt0035423     movie                             Kate & Leopold
# 4  tt0062336     movie  El Tango del Viudo y Su Espejo Deformante
# 5  tt0064730     movie                 Japan Organized Crime Boss
# 6  tt0065392     movie                         Bucharest Memories
# 7  tt0069049     movie                 The Other Side of the Wind
# 8  tt0087608     movie                           Leila wa al ziap
# 9  tt0088751     movie                          The Naked Monster
#
#                                originalTitle isAdult  startYear endYear  \
# 0                     La tierra de los toros       0     2000.0      \N
# 1                                 Frivolinas       0     2014.0      \N
# 2                                    Hongxia       0     2011.0      \N
# 3                             Kate & Leopold       0     2001.0      \N
# 4  El Tango del Viudo y Su Espejo Deformante       0     2020.0      \N
# 5                 Nihon boryoku-dan: Kumicho       0     2000.0      \N
# 6                       Amintiri bucurestene       0     2020.0      \N
# 7                 The Other Side of the Wind       0     2018.0      \N
# 8                           Leila wa al ziap       0     2008.0      \N
# 9                          The Naked Monster       0     2005.0      \N
#
#   runtimeMinutes                  genres  averageRating  numVotes
# 0             60                      \N            5.4        11
# 1             80          Comedy,Musical            5.6        15
# 2             94                      \N            6.3        52
# 3            118  Comedy,Fantasy,Romance            6.4     78723
# 4             70                   Drama            6.4       125
# 5             97            Action,Crime            7.0       172
# 6             \N             Documentary            6.3         7
# 7            122                   Drama            6.8      6201
# 8             90             Documentary            7.7        13
# 9            100    Comedy,Horror,Sci-Fi            5.4       274

# %%
votes = output1[output1['numVotes'] > 40000]
votes.head(10)
# Out:
#        tconst titleType                                       primaryTitle  \
# 3   tt0035423     movie                                     Kate & Leopold
# 39  tt0118694     movie                               In the Mood for Love
# 66  tt0120630     movie                                        Chicken Run
# 67  tt0120667     movie                                     Fantastic Four
# 69  tt0120679     movie                                              Frida
# 70  tt0120681     movie                                          From Hell
# 73  tt0120737     movie  The Lord of the Rings: The Fellowship of the Ring
# 75  tt0120755     movie                             Mission: Impossible II
# 76  tt0120804     movie                                      Resident Evil
# 80  tt0120903     movie                                              X-Men
#
#                                         originalTitle isAdult  startYear  \
# 3                                      Kate & Leopold       0     2001.0
# 39                                   Fa yeung nin wah       0     2000.0
# 66                                        Chicken Run       0     2000.0
# 67                                     Fantastic Four       0     2005.0
# 69                                              Frida       0     2002.0
# 70                                          From Hell       0     2001.0
# 73  The Lord of the Rings: The Fellowship of the Ring       0     2001.0
# 75                             Mission: Impossible II       0     2000.0
# 76                                      Resident Evil       0     2002.0
# 80                                              X-Men       0     2000.0
#
#    endYear runtimeMinutes                      genres  averageRating  numVotes
# 3       \N            118      Comedy,Fantasy,Romance            6.4     78723
# 39      \N             98               Drama,Romance            8.1    123081
# 66      \N             84  Adventure,Animation,Comedy            7.0    176398
# 67      \N            106    Action,Adventure,Fantasy            5.7    310626
# 69      \N            123     Biography,Drama,Romance            7.4     81034
# 70      \N            122     Horror,Mystery,Thriller            6.8    146363
# 73      \N            178      Action,Adventure,Drama            8.8   1649550
# 75      \N            123   Action,Adventure,Thriller            6.1    313298
# 76      \N            100        Action,Horror,Sci-Fi            6.7    246619
# 80      \N            104     Action,Adventure,Sci-Fi            7.4    568549

# %%
Output2 = votes.sort_values('averageRating', ascending = False)
Output2.head(20)
# Out:
#             tconst titleType  \
# 78678    tt2592910     movie
# 20012    tt0468569     movie
# 366      tt0167260     movie
# 47583    tt1375666     movie
# 111783   tt5813916     movie
# 73       tt0120737     movie
# 30112   tt10189514     movie
# 367      tt0167261     movie
# 119496   tt6751668     movie
# 7553     tt0317248     movie
# 2348     tt0245429     movie
# 130024   tt8503618     movie
# 24725    tt0816692     movie
# 56810    tt1675434     movie
# 2801     tt0253474     movie
# 418      tt0172495     movie
# 78561    tt2582802     movie
# 21430    tt0482571     movie
# 48958    tt1424432     movie
# 14633    tt0407887     movie
#
#                                              primaryTitle  \
# 78678                              CM101MMXI Fundamentals
# 20012                                     The Dark Knight
# 366         The Lord of the Rings: The Return of the King
# 47583                                           Inception
# 111783                                    The Mountain II
# 73      The Lord of the Rings: The Fellowship of the Ring
# 30112                                     Soorarai Pottru
# 367                 The Lord of the Rings: The Two Towers
# 119496                                           Parasite
# 7553                                          City of God
# 2348                                        Spirited Away
# 130024                                           Hamilton
# 24725                                        Interstellar
# 56810                                    The Intouchables
# 2801                                          The Pianist
# 418                                             Gladiator
# 78561                                            Whiplash
# 21430                                        The Prestige
# 48958                                               Senna
# 14633                                        The Departed
#
#                                             originalTitle isAdult  startYear  \
# 78678                              CM101MMXI Fundamentals       0     2013.0
# 20012                                     The Dark Knight       0     2008.0
# 366         The Lord of the Rings: The Return of the King       0     2003.0
# 47583                                           Inception       0     2010.0
# 111783                                             Dag II       0     2016.0
# 73      The Lord of the Rings: The Fellowship of the Ring       0     2001.0
# 30112                                     Soorarai Pottru       0     2020.0
# 367                 The Lord of the Rings: The Two Towers       0     2002.0
# 119496                                       Gisaengchung       0     2019.0
# 7553                                       Cidade de Deus       0     2002.0
# 2348                        Sen to Chihiro no kamikakushi       0     2001.0
# 130024                                           Hamilton       0     2020.0
# 24725                                        Interstellar       0     2014.0
# 56810                                        Intouchables       0     2011.0
# 2801                                          The Pianist       0     2002.0
# 418                                             Gladiator       0     2000.0
# 78561                                            Whiplash       0     2014.0
# 21430                                        The Prestige       0     2006.0
# 48958                                               Senna       0     2010.0
# 14633                                        The Departed       0     2006.0
#
#        endYear runtimeMinutes                       genres  averageRating  \
# 78678       \N            139           Comedy,Documentary            9.2
# 20012       \N            152           Action,Crime,Drama            9.0
# 366         \N            201       Action,Adventure,Drama            8.9
# 47583       \N            148      Action,Adventure,Sci-Fi            8.8
# 111783      \N            135             Action,Drama,War            8.8
# 73          \N            178       Action,Adventure,Drama            8.8
# 30112       \N            153                        Drama            8.7
# 367         \N            179       Action,Adventure,Drama            8.7
# 119496      \N            132        Comedy,Drama,Thriller            8.6
# 7553        \N            130                  Crime,Drama            8.6
# 2348        \N            125   Adventure,Animation,Family            8.6
# 130024      \N            160      Biography,Drama,History            8.6
# 24725       \N            169       Adventure,Drama,Sci-Fi            8.6
# 56810       \N            112       Biography,Comedy,Drama            8.5
# 2801        \N            150        Biography,Drama,Music            8.5
# 418         \N            155       Action,Adventure,Drama            8.5
# 78561       \N            106                  Drama,Music            8.5
# 21430       \N            130         Drama,Mystery,Sci-Fi            8.5
# 48958       \N            106  Biography,Documentary,Sport            8.5
# 14633       \N            151         Crime,Drama,Thriller            8.5
#
#         numVotes
# 78678      43813
# 20012    2288140
# 366      1632805
# 47583    2051750
# 111783    104744
# 73       1649550
# 30112      51610
# 367      1476251
# 119496    530801
# 7553      696002
# 2348      644957
# 130024     51526
# 24725    1496586
# 56810     753012
# 2801      724139
# 418      1333117
# 78561     710559
# 21430    1181694
# 48958      63861
# 14633    1181716

# %%
Output2['originalTitle'].head(20)
# Out:
# 78678                                CM101MMXI Fundamentals
# 20012                                       The Dark Knight
# 366           The Lord of the Rings: The Return of the King
# 47583                                             Inception
# 111783                                               Dag II
# 73        The Lord of the Rings: The Fellowship of the Ring
# 30112                                       Soorarai Pottru
# 367                   The Lord of the Rings: The Two Towers
# 119496                                         Gisaengchung
# 7553                                         Cidade de Deus
# 2348                          Sen to Chihiro no kamikakushi
# 130024                                             Hamilton
# 24725                                          Interstellar
# 56810                                          Intouchables
# 2801                                            The Pianist
# 418                                               Gladiator
# 78561                                              Whiplash
# 21430                                          The Prestige
# 48958                                                 Senna
# 14633                                          The Departed
# Name: originalTitle, dtype: object
