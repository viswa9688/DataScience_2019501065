# %%
import glob
import csv
import os
import pandas as pd

# %%
for files in glob.glob('C:\\Users\\HARIKA\\Desktop\\DataScience_2019501065\\DADV_FinalExam\\Day\\*.csv'):
    f = open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    data = pd.read_csv(f)
    lis = []
    for each in range(0, len(data)-1):
        row2 = data.iloc[each]
        row1 = data.iloc[each+1]
        gl = (row2["Close"] + row1["Close"]) / row1["Close"]
        lis.append(gl)
    lis.insert(0,0)
    data.loc[:,'gainORloss'] = lis
    data.to_csv(r'C:\\Users\\HARIKA\\Desktop\\DataScience_2019501065\\DADV_FinalExam\\Day\\'+name+'.csv')
    f.close()
print(lis)
# Out:
# [0, 1.9821278139590108, 2.0158865531914896, 2.0025597269624575, 2.00056918043737, 1.9859708189105167, 2.0079184952511735, 2.0042602102885607, 2.011200430786904, 2.0043265650029745, 1.9936944394867997, 1.9968571142857143, 1.994318153570507, 2.063444203229257, 2.001815889775548, 2.010397553198852, 2.004917025048647, 2.014971927168686, 2.0037570443407313, 1.993777286676331, 2.0031210361073333, 2.010725551712128, 2.0095541719745222, 1.984943569163851, 1.9873025089098013, 2.003106617058298, 2.0031162044250546, 1.993498482770851, 2.011587817099906, 1.9962558813184363, 1.9834304694691622, 2.0049337033610857, 2.003093040328299, 1.986272208245034, 2.0083051681516557, 2.00556746021853, 1.9926313171630334, 2.0077351485148514, 1.9953803204379328, 2.0018513113236653, 1.9917380660954713, 1.9790293295677253, 1.9872818696456114, 1.9994087792250206, 1.989760152135752, 1.9950510040786613, 2.066107912287153, 1.990774938499385, 1.9809954159278786, 2.029823020497764, 1.9938252545176058, 2.01218746875, 2.
# ...

# %%
for files in glob.glob('C:\\Users\\HARIKA\\Desktop\\DataScience_2019501065\\DADV_FinalExam\\Month\\*.csv'):
    f=open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    data = pd.read_csv(f)
    lis = []
    for each in range(0, len(data)-1):
        row2 = data.iloc[each]
        row1 = data.iloc[each+1]
        gl = (row2["Close"] + row1["Close"]) / row1["Close"]
        lis.append(gl)
    lis.insert(0,0)
    data.loc[:,'gainORloss'] = lis
    data.to_csv(r'C:\\Users\\HARIKA\\Desktop\\DataScience_2019501065\\DADV_FinalExam\\Month\\'+name+'.csv')
    f.close()

# %%
for files in glob.glob('C:\\Users\\HARIKA\\Desktop\\DataScience_2019501065\\DADV_FinalExam\\Week\\*.csv'):
    f=open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    data = pd.read_csv(f)
    lis = []
    for each in range(0, len(data)-1):
        row2 = data.iloc[each]
        row1 = data.iloc[each+1]
        gl = (row2["Close"] + row1["Close"]) / row1["Close"]
        lis.append(gl)
    lis.insert(0,0)
    data.loc[:,'gainORloss'] = lis
    data.to_csv(r'C:\\Users\\HARIKA\\Desktop\\DataScience_2019501065\\DADV_FinalExam\\Week\\'+name+'.csv')
    f.close()
# print("harika")
# Out:
# harika
